# %%
#MAT 201A Homework4
#Intae Hwang 7 Feb 2015
#Picture from
#http://en.wikipedia.org/wiki/Raphael
#The Madonna of the Meadow, c. 1506,

# %%
# %pylab inline
rcParams['figure.figsize'] = (10, 4) 
from __future__ import print_function
from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt

# %%
i = imread('/Users/intaehwang/Desktop/ra.png')
subplot(121)
imshow(i)

i2 = imread('/Users/intaehwang/Desktop/ra3.png')
subplot(122)
imshow(i2)

# %%
i.shape
# Out:
# (1956, 1584, 3)

# %%
i.ndim
# Out:
# 3

# %%
i = np.array(tuple(i))

# %%
i.dtype
# Out:
# dtype('float32')

# %%
i2.shape
# Out:
# (269, 295, 3)

# %%
i2.dtype
# Out:
# dtype('float32')

# %%
i2.ndim
# Out:
# 3

# %%
i2 = np.array(tuple(i2))

# %%
i = sum(i.astype(float), axis=2)/4.0
imshow(i)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x122f637e8>

# %%
i2 = sum(i2.astype(float), axis=2)/4.0
subplot(122)
imshow(i2)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x109428638>

# %%
subplot(121)
imshow(i, cmap=cm.gray)
colorbar()

subplot(122)
imshow(i2, cmap=cm.gray)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x109a355a8>

# %%
subplot(121)
i = where(i > 1.5, -2, 2)
imshow(i, cmap='gray')
colorbar()

subplot(122)
i2 = where(i2 > 1.5, -2, 2)
imshow(i2, cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x17191fd88>

# %%
import scipy.signal

# %%
from scipy.signal import correlate2d
cc = correlate2d(i, i2)
imshow(cc)
colorbar()
gcf().set_figheight(8)

# %%
imshow(cc, cmap=cm.gray)
colorbar()
gcf().set_figheight(8)

# %%
imshow(where(cc > 0.5, 1, 0), interpolation='nearest', cmap=cm.gray)
colorbar()
gcf().set_figheight(8)
