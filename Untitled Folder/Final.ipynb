# %% [markdown]
# # MAT 201A Final Project
# Intae Hwang Winter 2015
#
# The goal of this project is to address one of image filter which transfroms original image more like to oil painting image. Instead photoshop, using python program I will perform the filtering process with pictures in the campus taken by myself. The result will be close to the Impressionism painting, for this I’m going to explore their color choice and brush stroke.

# %%
# %pylab inline
from __future__ import print_function
from __future__ import division
import Image
import ImageFilter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# This is the one of objectives for this project.
# "Blur" is one of technics that used by Impressionist.
#  Basically, all of details we can see through our eyes are diliuted,
#  then only afterimage is drawn on the canvas.

# %%
imgOriginal = imread('/Users/intaehwang/Desktop/Impression.jpg')
imshow(imgOriginal)
#http://en.wikipedia.org/wiki/Claude_Monet#mediaviewer/File:Claude_Monet,_Impression,_soleil_levant.jpg

# %% [markdown]
# I choose this for the first sample image = "Coral Tree"

# %%
img = imread('/Users/intaehwang/Desktop/coral2.jpg')
imshow(img)

# %%
im = Image.open('/Users/intaehwang/Desktop/coral2.jpg').convert("L")
imshow(im)

# %% [markdown]
# # 'ImageEnhance

# %% [markdown]
# First, I tried increasing contrast

# %%
import ImageEnhance

# %%
enh = ImageEnhance.Contrast(im)
enh.enhance(9.9).show("30% more contrast")

# %% [markdown]
# # Move to Top-hat transform

# %%
import scipy.ndimage.morphology as morphology
import sys 
import numpy
from PIL import Image

# %%
mg = morphology.morphological_gradient(img, (10,10,10))
imshow(mg)

# %% [markdown]
# White top-hat seems work for my intension, I tried to more.

# %%
import sys
import numpy
from PIL import Image


im = numpy.array(img)
fft_mag = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(im)))

visual = numpy.log(fft_mag)
visual = (visual - visual.min()) / (visual.max() - visual.min())

result = Image.fromarray((visual * 255).astype(numpy.uint8))
result.save('/Users/intaehwang/Desktop/out.bmp')
# Out:
# /Users/intaehwang/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:9: RuntimeWarning: divide by zero encountered in log
# /Users/intaehwang/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: invalid value encountered in subtract
# /Users/intaehwang/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:10: RuntimeWarning: invalid value encountered in true_divide

# %%
wtp = morphology.white_tophat(img, (15,15,15))
imshow(wtp);

# %%
scr=wtp[2000:3000, 1000:2000]
subplot(121)
imshow(scr)
scr1=img[2000:3000, 1000:2000]
subplot(122)
imshow(scr1)

# %% [markdown]
#  Black top-hat gives more dramatic color changes.

# %%
btp = morphology.black_tophat(img, (10,10,10))
imshow(btp);

# %%
btp = morphology.black_tophat(img, (1,1,10))
imshow(btp);

# %%
btp = morphology.black_tophat(img, (100,10,100))
imshow(btp);

# %%
btp = morphology.black_tophat(img, (100,10,10))
imshow(btp);

# %%
from PIL import Image
import glob, os

# %%
scr=btp[2000:3000, 1000:2000]
subplot(121)
imshow(scr)
scr1=img[2000:3000, 1000:2000]
subplot(122)
imshow(scr1)

# %%
btp.shape
# Out:
# (4608, 2592, 3)

# %%
import scipy.ndimage as ndimage

# %%
def imshow2(btp):
    imshow(btp)

# %%
c3 = ndimage.median_filter(btp, size=10,footprint=None)
imshow2(c3)

# %%
scr=btp[2000:3000, 1000:2000]
subplot(121)
imshow(scr)
scr=c3[2000:3000, 1000:2000]
subplot(122)
imshow(scr)
